# %% [markdown]
# Install Faker

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.12.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.12.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.3 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.12.0

# %%
from faker import Faker

# %%
fake = Faker()

# %% [markdown]
# Data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
names = [fake.name() for _ in range(250)]
data={
"student id":np.random.randint(18,65,250),
"Name":np.random.choice(names,250),
"Gender":np.random.choice(["Male","Female"],250),
"Department":np.random.choice(["IT","HR","Finance","Marketing","Sales"],250),
"Year":np.random.randint(2025,2028,250),
"Maths":np.random.randint(0,100,250),
"science":np.random.randint(0,100,250),
"English":np.random.randint(0,100,250),
"Attendence":np.random.randint(50,100,250),
"Internal mark":np.random.randint(0,25,250)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      student id             Name Gender Department  Year  Maths  science  \
# 0            64  Stephanie Ortiz   Male         HR  2027     94       58
# 1            31       Tanya Diaz   Male  Marketing  2026     83       65
# 2            37  Michelle Macias   Male         HR  2027     48       80
# 3            21   Sophia Brennan   Male    Finance  2025     29       86
# 4            24       Maria Carr   Male      Sales  2025     29        5
# ..          ...              ...    ...        ...   ...    ...      ...
# 245          39    Kaitlin Lopez   Male    Finance  2027     31       34
# 246          55     Bernard Choi   Male         HR  2027     81       87
# 247          48     Angel Powell   Male         HR  2026     47       28
# 248          34    Meghan Morris   Male  Marketing  2026     99       44
# 249          33    Michael Weeks   Male         HR  2025      8       64
#
#      English  Attendence  Internal mark
# 0         98          79              5
# 1         21          52             12
# 2         70          62              3
# 3         65          63              3
# 4         56          77              2
# ..       ...         ...            ...
# 245       98          64              9
# 246       54          69             15
# 247        6          54              7
# 248       61          62              4
# 249       75          97             23
#
# [250 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# student id       0
# Name             0
# Gender           0
# Department       0
# Year             0
# Maths            0
# science          0
# English          0
# Attendence       0
# Internal mark    0
# dtype: int64

# %%
df["Total"] = df["Maths"] + df["science"] + df["English"]
df["Average"] = df["Total"] / 3

# %%
def grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 75:
        return "B"
    elif avg >= 50:
        return "C"
    else:
        return "Fail"

# %%
df.describe()
# Out:
#        student id         Year      Maths     science     English  Attendence  \
# count  250.000000   250.000000  250.00000  250.000000  250.000000  250.000000
# mean    40.912000  2026.064000   49.38800   50.968000   53.896000   75.732000
# std     14.255002     0.813974   29.13377   30.213547   28.277405   14.030238
# min     18.000000  2025.000000    0.00000    0.000000    0.000000   50.000000
# 25%     28.000000  2025.000000   23.00000   25.000000   32.250000   64.000000
# 50%     41.000000  2026.000000   49.50000   53.000000   55.000000   76.500000
# 75%     53.000000  2027.000000   74.00000   77.000000   79.000000   88.000000
# max     64.000000  2027.000000   99.00000   99.000000   99.000000   99.000000
#
#        Internal mark       Total     Average
# count     250.000000  250.000000  250.000000
# mean       11.684000  154.252000   51.417333
# std         7.048323   50.064903   16.688301
# min         0.000000   30.000000   10.000000
# 25%         6.000000  119.250000   39.750000
# 50%        11.000000  159.000000   53.000000
# 75%        18.000000  190.750000   63.583333
# max        24.000000  273.000000   91.000000

# %% [markdown]
# BAR CHART

# %%
dept_avg = df.groupby("Department")["Average"].mean()

dept_avg.plot(kind='bar')
plt.title("Department-wise Performance")
plt.xlabel("Department")
plt.ylabel("Average Marks")
plt.show()

# %% [markdown]
# Pie chart

# %%
plt.figure()
df["Gender"].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# Histogram

# %%
plt.figure()
plt.hist(df["Average"], bins=10)
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Scatter plot

# %%
plt.figure()
plt.scatter(df["Attendence"], df["Average"])
plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance")
plt.ylabel("Average Marks")
plt.show()
